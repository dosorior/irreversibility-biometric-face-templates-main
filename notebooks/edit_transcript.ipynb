# %%
import os

# %%
with open('TranscriptDE.txt.txt') as f:
    lines = f.readlines()
    
lines
# Out:
# ['00:00:07:18 - 00:00:12:09\n',
#  'Volkmar, im Februar hatten wir unseren\n',
#  'erster Intranet-Artikel zum Projekt EAGLES,\n',
#  '\n',
#  '00:00:12:09 - 00:00:17:09\n',
#  'Und heute sind wir hier, um einen Überblick zu geben\n',
#  'und über ein Update zu sprechen.\n',
#  '\n',
#  '00:00:17:18 - 00:00:22:11\n',
#  'Kannst Du unsere Zuschauer erstmal informieren,\n',
#  'worum es bei diesem Projekt geht?\n',
#  '\n',
#  '00:00:23:02 - 00:00:28:00\n',
#  'Zunächst einmal sind Servicelösungen ein Schlüsselelement der zukünftigen Wachstumsstrategie von SMY,\n',
#  '\n',
#  '00:00:28:10 - 00:00:31:03\n',
#  'und wir haben ein großartiges technologisches Fundament am Start.\n',
#  '\n',
#  '00:00:31:22 - 00:00:35:19\n',
#  'Deshalb schauen wir uns genau an, wie wir noch stärker zusammenarbeiten können\n',
#  '\n',
#  '00:00:35:19 - 00:00:37:03\n',
#  'in diesem Bereich.\n',
#  '\n',
#  '00:00:37:03 - 00:00:39:12\n',
#  'Wir haben erkannt, dass es Verbesserungspotenzial gibt.\n',
# ...

# %%
for line in lines:
    if line[0] == '0':
        lines.remove(line)

with open('TranscriptDE-edit.txt.txt', 'w') as f:
    for line in lines:
        f.write(line)
