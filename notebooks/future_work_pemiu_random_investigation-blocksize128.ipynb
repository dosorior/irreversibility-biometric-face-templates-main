# %%
# System
import os
import random

# Data preparation
import pandas as pd
import numpy as np
import math

# Plotting
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import seaborn as sns
import svgutils.compose as sc
from IPython.display import SVG

# Calculations: Normalization, cosine distance
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial import distance
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Settings
# %matplotlib inline
rcParams['figure.figsize'] = 8, 8
# sns.set_style('whitegrid')

# Custom
from recreate_icip2022_face_reconstruction.GenerateSampleImages import GenerateSampleImagesFromEmbeddings
from recreate_icip2022_face_reconstruction.src.pemiu.privacy_enhancing_miu import PrivacyEnhancingMIU
from recreate_icip2022_face_reconstruction.src.GenerateEmbeddings import GenerateEmbeddings

pd.set_option("display.max_colwidth", 10000)

import shutil

# %% [markdown]
# ---
#
# ## Investigation of fixed seed in PE-MIU shuffle method
#
# Description tbd

# %%
# Global variables
block_sizes = ["16", "32", "64", "128"]
block_size = 128

# Paths
experiment_11_path = "../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/"

# %%
# Helper methods

def one_sample_per_subject(dataframe, evaluation_criteria: str):
    """
    Return a dataframe of LFW image set with only one sample per subject.
    If a subject has more than one sample, it is compared to the other choices by the provided evaluation criterion.

    Args:
        dataframe ():
        evaluation_criteria (): Dataframe column name. Valid choices, e.g.:
                                - img_original_quality

    Returns: pd.DataFrame
    """
    # Dataset should only include one sample per subject
    # Create a dict with name of subject as key and an empty list as value
    subjects = dataframe['filename'].apply(lambda x: x.split('_')[:-1]).tolist()
    subjects = ['_'.join(x) for x in subjects]
    indices = [[] for _ in range(len(subjects))]
    subjects_dict = dict(zip(subjects, indices))
    # Store row indices for each subject as values
    for index, row in dataframe.iterrows():
        if '_'.join(row['filename'].split('_')[:-1]) in subjects_dict:
            subjects_dict['_'.join(row['filename'].split('_')[:-1])].append(index)
    # Iterate over dict, remove all values except one for each key
    for key, value in subjects_dict.items():
        if len(value) > 1:
            # We keep the sample with the greatest value considering the evaluation criteria
            # Get all rows for indices of this subject as series.
            data = dataframe.iloc[subjects_dict[key]]
            # Get the index of the sample with the greatest value considering the criteria
            # Reduce the values to the chosen sample.
            subjects_dict[key] = [data[evaluation_criteria].idxmax()]
    # Iterate over dataframe.
    # Remove all rows which are not in the dictionary containing only unique subjects and samples
    for index, row in dataframe.iterrows():
        if [index] not in subjects_dict.values():
            dataframe.drop(index, inplace=True)

    return dataframe

# %%
# Load and modify dataframes
df = pd.read_csv("../evaluation/lfw_complete_genders_with_quality.csv", sep=",")
df = df[['lfw_image', 'img_original_quality', 'lfw_embedding', 'lfw_filename_raw', 'gender_official']]

# Add filename, remove file extension
df['filename'] = df['lfw_filename_raw'].apply(lambda x: x.split('.')[0])
df.drop(columns='lfw_filename_raw', inplace=True)

df.rename(columns={'lfw_embedding': 'embedding_original_arcface'}, inplace=True)
df.rename(columns={'lfw_image': 'img_original'}, inplace=True)

df['embedding_original_elasticface'] = df['filename'].apply(lambda x: f"../data/lfw_align_embeddings_elastic/{x}.npy")

# Only include one sample per identity: the one with the highest image quality.
df = one_sample_per_subject(df, "img_original_quality")

# Balance dataset to include a 50/50 amount of male and female samples
num_female = len(df[df["gender_official"] == "F"])
# Get indices of rows with male gender
male_indices = df[df['gender_official'] == "M"].index
# Reduce amount of male indices so that the total matches the number of female samples
male_indices = male_indices[num_female:]
# Drop superfluous indices
df = df.drop(male_indices)

# Samples have missing genders. Drop them.
df = df.drop(df[df['gender_official'] == "X"].index)

# Reset df index
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                                     img_original  \
# 0         ../data/lfw_align/Aaron_Eckhart/Aaron_Eckhart_0001.png
# 1             ../data/lfw_align/Aaron_Guiel/Aaron_Guiel_0001.png
# 2     ../data/lfw_align/Aaron_Patterson/Aaron_Patterson_0001.png
# 3         ../data/lfw_align/Aaron_Peirsol/Aaron_Peirsol_0004.png
# 4               ../data/lfw_align/Aaron_Pena/Aaron_Pena_0001.png
# ...                                                          ...
# 2937        ../data/lfw_align/Zelma_Novelo/Zelma_Novelo_0001.png
# 2938            ../data/lfw_align/Zhang_Ziyi/Zhang_Ziyi_0003.png
# 2939                ../data/lfw_align/Zoe_Ball/Zoe_Ball_0001.png
# 2940    ../data/lfw_align/Zorica_Radovic/Zorica_Radovic_0001.png
# 2941        ../data/lfw_align/Zumrati_Juma/Zumrati_Juma_0001.png
#
#       img_original_quality                         embedding_original_arcface  \
# 0                 0.785188    ../data/features_cleaner/Aaron_Eckhart_0001.npy
# 1                 0.764814      ../data/features_cleaner/Aaron_Guiel_0001.npy
# 2                 0.737193  ../data/features_cleaner/Aaron_Patterson_0001.npy
# 3                 0.810206    ../data/features_cleaner/Aaron_Peirsol_0004.npy
# 4                 0.829048       ../data/features_cleaner/Aaron_Pena_0001.npy
# ...                    ...                                                ...
# 2937              0.834612     ../data/features_cleaner/Zelma_Novelo_0001.npy
# 2938              0.696282       ../data/features_cleaner/Zhang_Ziyi_0003.npy
# 2939              0.779261         ../data/features_cleaner/Zoe_Ball_0001.npy
# 2940              0.741519   ../data/features_cleaner/Zorica_Radovic_0001.npy
# 2941              0.470757     ../data/features_cleaner/Zumrati_Juma_0001.npy
#
#      gender_official              filename  \
# 0                  M    Aaron_Eckhart_0001
# 1                  M      Aaron_Guiel_0001
# 2                  M  Aaron_Patterson_0001
# 3                  M    Aaron_Peirsol_0004
# 4                  M       Aaron_Pena_0001
# ...              ...                   ...
# 2937               F     Zelma_Novelo_0001
# 2938               F       Zhang_Ziyi_0003
# 2939               F         Zoe_Ball_0001
# 2940               F   Zorica_Radovic_0001
# 2941               F     Zumrati_Juma_0001
#
#                                      embedding_original_elasticface
# 0       ../data/lfw_align_embeddings_elastic/Aaron_Eckhart_0001.npy
# 1         ../data/lfw_align_embeddings_elastic/Aaron_Guiel_0001.npy
# 2     ../data/lfw_align_embeddings_elastic/Aaron_Patterson_0001.npy
# 3       ../data/lfw_align_embeddings_elastic/Aaron_Peirsol_0004.npy
# 4          ../data/lfw_align_embeddings_elastic/Aaron_Pena_0001.npy
# ...                                                             ...
# 2937     ../data/lfw_align_embeddings_elastic/Zelma_Novelo_0001.npy
# 2938       ../data/lfw_align_embeddings_elastic/Zhang_Ziyi_0003.npy
# 2939         ../data/lfw_align_embeddings_elastic/Zoe_Ball_0001.npy
# 2940   ../data/lfw_align_embeddings_elastic/Zorica_Radovic_0001.npy
# 2941     ../data/lfw_align_embeddings_elastic/Zumrati_Juma_0001.npy
#
# [2942 rows x 6 columns]

# %%
df['gender_official'].value_counts()
# Out:
# M    1471
# F    1471
# Name: gender_official, dtype: int64

# %%
print('Column names:\n')
print('\n'.join(df.columns.to_list()))
# Out:
# Column names:
#
# img_original
# img_original_quality
# embedding_original_arcface
# gender_official
# filename
# embedding_original_elasticface

# %% [markdown]
# ---
#
# ### Seed discovery

# %%
target_a = df.iloc[0:1,:]['embedding_original_arcface'].to_string(header=False, index=False)
target_a
# Out:
# '../data/features_cleaner/Aaron_Eckhart_0001.npy'

# %%
target_a = [np.load(target_a)]

# %%
# Initialize PE-MIU
pemiu = PrivacyEnhancingMIU(block_size=block_size)
random_results = {}
amount = 1000

# Go trough j random seeds, shuffle the vector, store the permutation degree (0, 128, 256, 512)
# Higher result means less permutation
for j in range(0, amount):
    random.seed(j)
    target_a_shuffled = pemiu.shuffle(target_a)
    positions = [target_a[i] == target_a_shuffled[i] for i in range(len(target_a))]
    random_results[j] = sum(positions[0])

# %%
# Create a dict with the seeds and desription
seed_dict = {}

# %%
# Seed where items are not shuffled
for k, v in random_results.items():
    if v == 512:
        seed_dict[k] = "Items are not shuffled"
        break

# %%
# Seed where only half of the blocks are shuffled
reduce_duplicated = {}
sequence_original = [x for x in range(0, 4)]
sequence_shuffle = sequence_original.copy()

for k, v in random_results.items():
    if v == 256:
        exists = False
        # Use the seed to shuffle a sequence of four numbers
        sequence_shuffle = sequence_original.copy()
        random.seed(k)
        random.shuffle(sequence_shuffle)
        # Add seed to reduced dict if this exact shuffle is not already present
        for key, value in reduce_duplicated.items():
            if value == sequence_shuffle:
                exists = True
        if not exists:
            reduce_duplicated[k] = sequence_shuffle

for key, value in reduce_duplicated.items():
    seed_dict[key] = f"Half of the blocks shuffled, order: {value}"

# %%
# Seed where three of the four blocks are shuffled
reduce_duplicated = {}
sequence_original = [x for x in range(0, 4)]
sequence_shuffle = sequence_original.copy()

for k, v in random_results.items():
    if v == 128:
        exists = False
        # Use the seed to shuffle a sequence of four numbers
        sequence_shuffle = sequence_original.copy()
        random.seed(k)
        random.shuffle(sequence_shuffle)
        # Add seed to reduced dict if this exact shuffle is not already present
        for key, value in reduce_duplicated.items():
            if value == sequence_shuffle:
                exists = True
        if not exists:
            reduce_duplicated[k] = sequence_shuffle

for key, value in reduce_duplicated.items():
    seed_dict[key] = f"Three of the blocks shuffled, order: {value}"

# %%
# All blocks are shuffled
reduce_duplicated = {}
sequence_original = [x for x in range(0, 4)]
sequence_shuffle = sequence_original.copy()

for k, v in random_results.items():
    if v == 0:
        exists = False
        # Use the seed to shuffle a sequence of four numbers
        sequence_shuffle = sequence_original.copy()
        random.seed(k)
        random.shuffle(sequence_shuffle)
        # Add seed to reduced dict if this exact shuffle is not already present
        for key, value in reduce_duplicated.items():
            if value == sequence_shuffle:
                exists = True
        if not exists:
            reduce_duplicated[k] = sequence_shuffle

for key, value in reduce_duplicated.items():
    seed_dict[key] = f"All blocks are shuffled: {value}"

# %%
for key, value in seed_dict.items():
    print(key, "\t",value)
# Out:
# 9 	 Items are not shuffled
# 5 	 Half of the blocks shuffled, order: [0, 1, 3, 2]
# 12 	 Half of the blocks shuffled, order: [0, 2, 1, 3]
# 24 	 Half of the blocks shuffled, order: [1, 0, 2, 3]
# 64 	 Half of the blocks shuffled, order: [2, 1, 0, 3]
# 86 	 Half of the blocks shuffled, order: [3, 1, 2, 0]
# 101 	 Half of the blocks shuffled, order: [0, 3, 2, 1]
# 0 	 Three of the blocks shuffled, order: [2, 0, 1, 3]
# 1 	 Three of the blocks shuffled, order: [3, 0, 2, 1]
# 7 	 Three of the blocks shuffled, order: [3, 1, 0, 2]
# 8 	 Three of the blocks shuffled, order: [0, 2, 3, 1]
# 14 	 Three of the blocks shuffled, order: [1, 3, 2, 0]
# 16 	 Three of the blocks shuffled, order: [0, 3, 1, 2]
# 25 	 Three of the blocks shuffled, order: [1, 2, 0, 3]
# 42 	 Three of the blocks shuffled, order: [2, 1, 3, 0]
# 2 	 All blocks are shuffled: [1, 2, 3, 0]
# 4 	 All blocks are shuffled: [2, 0, 3, 1]
# 6 	 All blocks are shuffled: [3, 2, 1, 0]
# 13 	 All blocks are shuffled: [3, 0, 1, 2]
# 15 	 All blocks are shuffled: [3, 2, 0, 1]
# 18 	 All blocks are shuffled: [2, 3, 0, 1]
# 23 	 All blocks are shuffled: [1, 3, 0, 2]
# 30 	 All blocks are shuffled: [1, 0, 3, 2]
# 31 	 All blocks are shuffled: [2, 3, 1, 0]

# %%
len(seed_dict)
# Out:
# 24

# %%
---

### Create PE-MIU embeddings with known seeds

# %%
for key, value in seed_dict.items():
    # Make dir
    save_path = f"{experiment_11_path}embedding_seed_{key}"
    os.makedirs(save_path, exist_ok=True)
    
    # Shuffle Pemiu with seed key for each embedding
    embeddings = [np.load(x) for x in df['embedding_original_arcface'].to_list()]
    embeddings_shuffled = []
    for element in embeddings:
        random.seed(key)
        embeddings_shuffled.append(pemiu.shuffle([element]))
    [np.save(f"{save_path}/{df['filename'][i]}.npy", embeddings_shuffled[i]) for i in range(len(df))]

# %% [markdown]
# ### Seed discovery reduced

# %%
target_a = df.iloc[0:1,:]['embedding_original_arcface'].to_string(header=False, index=False)
target_a = [np.load(target_a)]

# %%
# Initialize PE-MIU
pemiu = PrivacyEnhancingMIU(block_size=block_size)
random_results = {}
amount = 10000

# Go trough j random seeds, shuffle the vector, store the permutation degree (0, 64, 128, ...)
# Higher result means less permutation
for j in range(0, amount):
    random.seed(j)
    target_a_shuffled = pemiu.shuffle(target_a)
    positions = [target_a[i] == target_a_shuffled[i] for i in range(len(target_a))]
    random_results[j] = sum(positions[0])

# %%
# Create a dict with the seeds and description
seed_dict = {}
permutation_degree = [x * block_size for x in range(0, 5)]

# Go through seeds, take one seed for each permutation degree
for k, v in random_results.items():
    if v in permutation_degree:
        seed_dict[k] = v
        permutation_degree.remove(v)

# %%
# Permutation degrees that coudn't be found
permutation_degree
# Out:
# [384]

# %%
# Sort dict by permutation degree
seed_dict = dict(sorted(seed_dict.items(), key=lambda item: item[1], reverse=True))

# %%
# Seeds and their permutation degree
for key, value in seed_dict.items():
    print(key, "\t",value)
# Out:
# 9 	 512
# 5 	 256
# 0 	 128
# 2 	 0

# %%
len(seed_dict)
# Out:
# 4

# %% [markdown]
# ---
#
# ### Create image reconsutrctions and evaluate cosine similarity

# %%
for key, value in seed_dict.items():
    samples_exp_11 = GenerateSampleImagesFromEmbeddings(
        dataset_dir=experiment_11_path,
        embedding_dir=f"embedding_seed_{key}",
        image_dir=f"../data/lfw_align",
        file_appendix=f"exp11",
        save_path=f"{experiment_11_path}/sample_img_{key}",
        save_path_log=f"{experiment_11_path}/sample_img_{key}",
        generator_checkpoint_dir="../recreate_icip2022_face_reconstruction/training_files",
        epoch=90,
        write_original_img=False,
        create_subdirs=False,
        batch_size=32
    )
    samples_exp_11.generate()
# Out:
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done
#
# The torch device is: cuda
# Generating around 5760 samples
# Done

# %% [markdown]
# ---
#
# ### Evaluate

# %%
for key, value in seed_dict.items():
    # Load results
    df_results = pd.read_csv(f"{experiment_11_path}/sample_img_{key}/logs/sample_images_log_exp11.csv")
    df_results['filename'] = df_results['filename'].apply(lambda x: x.split('_exp11')[0])
    df_results = df_results[['filename', 'Cosine Distance Bona Fide Embedding vs Synthesised Image Embedding']]
    df_results.rename(columns={"Cosine Distance Bona Fide Embedding vs Synthesised Image Embedding": f'seed_{key}'}, inplace=True)
    # Append results to dataframe
    #f[f'seed_{key}'] = df_results['Cosine Distance Bona Fide Embedding vs Synthesised Image Embedding']
    df = df.merge(df_results, on='filename')

# %%
df
# Out:
#                                                     img_original  \
# 0         ../data/lfw_align/Aaron_Eckhart/Aaron_Eckhart_0001.png
# 1             ../data/lfw_align/Aaron_Guiel/Aaron_Guiel_0001.png
# 2     ../data/lfw_align/Aaron_Patterson/Aaron_Patterson_0001.png
# 3         ../data/lfw_align/Aaron_Peirsol/Aaron_Peirsol_0004.png
# 4               ../data/lfw_align/Aaron_Pena/Aaron_Pena_0001.png
# ...                                                          ...
# 2937        ../data/lfw_align/Zelma_Novelo/Zelma_Novelo_0001.png
# 2938            ../data/lfw_align/Zhang_Ziyi/Zhang_Ziyi_0003.png
# 2939                ../data/lfw_align/Zoe_Ball/Zoe_Ball_0001.png
# 2940    ../data/lfw_align/Zorica_Radovic/Zorica_Radovic_0001.png
# 2941        ../data/lfw_align/Zumrati_Juma/Zumrati_Juma_0001.png
#
#       img_original_quality                         embedding_original_arcface  \
# 0                 0.785188    ../data/features_cleaner/Aaron_Eckhart_0001.npy
# 1                 0.764814      ../data/features_cleaner/Aaron_Guiel_0001.npy
# 2                 0.737193  ../data/features_cleaner/Aaron_Patterson_0001.npy
# 3                 0.810206    ../data/features_cleaner/Aaron_Peirsol_0004.npy
# 4                 0.829048       ../data/features_cleaner/Aaron_Pena_0001.npy
# ...                    ...                                                ...
# 2937              0.834612     ../data/features_cleaner/Zelma_Novelo_0001.npy
# 2938              0.696282       ../data/features_cleaner/Zhang_Ziyi_0003.npy
# 2939              0.779261         ../data/features_cleaner/Zoe_Ball_0001.npy
# 2940              0.741519   ../data/features_cleaner/Zorica_Radovic_0001.npy
# 2941              0.470757     ../data/features_cleaner/Zumrati_Juma_0001.npy
#
#      gender_official              filename  \
# 0                  M    Aaron_Eckhart_0001
# 1                  M      Aaron_Guiel_0001
# 2                  M  Aaron_Patterson_0001
# 3                  M    Aaron_Peirsol_0004
# 4                  M       Aaron_Pena_0001
# ...              ...                   ...
# 2937               F     Zelma_Novelo_0001
# 2938               F       Zhang_Ziyi_0003
# 2939               F         Zoe_Ball_0001
# 2940               F   Zorica_Radovic_0001
# 2941               F     Zumrati_Juma_0001
#
#                                      embedding_original_elasticface  seed_9  \
# 0       ../data/lfw_align_embeddings_elastic/Aaron_Eckhart_0001.npy   0.388
# 1         ../data/lfw_align_embeddings_elastic/Aaron_Guiel_0001.npy   0.253
# 2     ../data/lfw_align_embeddings_elastic/Aaron_Patterson_0001.npy   0.358
# 3       ../data/lfw_align_embeddings_elastic/Aaron_Peirsol_0004.npy   0.383
# 4          ../data/lfw_align_embeddings_elastic/Aaron_Pena_0001.npy   0.485
# ...                                                             ...     ...
# 2937     ../data/lfw_align_embeddings_elastic/Zelma_Novelo_0001.npy   0.615
# 2938       ../data/lfw_align_embeddings_elastic/Zhang_Ziyi_0003.npy   0.207
# 2939         ../data/lfw_align_embeddings_elastic/Zoe_Ball_0001.npy   0.590
# 2940   ../data/lfw_align_embeddings_elastic/Zorica_Radovic_0001.npy   0.628
# 2941     ../data/lfw_align_embeddings_elastic/Zumrati_Juma_0001.npy   0.372
#
#       seed_5  seed_0  seed_2
# 0      0.296   0.208   0.049
# 1      0.130   0.091   0.015
# 2      0.343   0.123  -0.009
# 3      0.186   0.070  -0.011
# 4      0.284   0.141   0.046
# ...      ...     ...     ...
# 2937   0.336   0.133   0.023
# 2938   0.151   0.175   0.055
# 2939   0.378   0.132  -0.141
# 2940   0.356   0.254  -0.031
# 2941   0.143   0.199   0.168
#
# [2942 rows x 10 columns]

# %%
# Calculate median of cos_sim and std deviation
df_eval = pd.DataFrame()
for key, value in seed_dict.items():
    df_eval[f'seed_{key}_cos_sim_mean'] = [df[f'seed_{key}'].mean()]
    df_eval[f'seed_{key}_cos_sim_std'] = [df[f'seed_{key}'].std()]

# %%
df_eval
# Out:
#    seed_9_cos_sim_mean  seed_9_cos_sim_std  seed_5_cos_sim_mean  \
# 0             0.460504            0.120689              0.27658
#
#    seed_5_cos_sim_std  seed_0_cos_sim_mean  seed_0_cos_sim_std  \
# 0            0.100571             0.136834            0.081652
#
#    seed_2_cos_sim_mean  seed_2_cos_sim_std
# 0             0.003077            0.071419

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
labels = [x.split('_')[1] for x in df[df.columns[pd.Series(df.columns).str.startswith('seed_')]].columns.to_list()]
sns.barplot(data=df[df.columns[pd.Series(df.columns).str.startswith('seed_')]], 
            ax=ax, 
            estimator=np.mean, errorbar=('sd'), capsize=.2)
ax.set_xticklabels(labels, rotation=45)

# Thresholds
#for i, (th, value) in enumerate(zip(['FMR1000_TH', 'FMR100_TH', 'FMR10_TH'], [0.25, 0.17, 0.1])):
#    ax.axhline(y = value, 
#               color = sns.color_palette("colorblind")[i], linestyle="--",
#               label = f"{th}: {value}")
#ax.legend()

plt.show()

# %% [markdown]
# ### Evaluate attack success rate

# %%
df_fmr1000, df_fmr100, df_fmr10 = pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

for th_label, th_value in zip(['FMR1000_TH', 'FMR100_TH', 'FMR10_TH'], [0.25, 0.17, 0.1]):
    print(th_label)
    for key, value in seed_dict.items():
        # Load results
        # df_results = pd.read_csv(f"{experiment_path}/sample_img_{key}/logs/sample_images_log_{experiment_appendix}.csv")
        # Append results to dataframe
        length = len(df)
        success = len(df[df[f'seed_{key}'] > th_value])
        print(f"Seed: {key}     \t Attack success rate: {round(success / length * 100, 2)}%")
        if th_label == "FMR1000_TH":
            df_fmr1000[key] = [round(success / length * 100, 2)]
        elif th_label == "FMR100_TH":
            df_fmr100[key] = [round(success / length * 100, 2)]
        elif th_label == "FMR10_TH":
            df_fmr10[key] = [round(success / length * 100, 2)]
    print("\n")
# Out:
# FMR1000_TH
# Seed: 9     	 Attack success rate: 94.6%
# Seed: 5     	 Attack success rate: 60.58%
# Seed: 0     	 Attack success rate: 8.83%
# Seed: 2     	 Attack success rate: 0.03%
#
#
# FMR100_TH
# Seed: 9     	 Attack success rate: 98.0%
# Seed: 5     	 Attack success rate: 85.93%
# Seed: 0     	 Attack success rate: 32.76%
# Seed: 2     	 Attack success rate: 1.19%
#
#
# FMR10_TH
# Seed: 9     	 Attack success rate: 98.88%
# Seed: 5     	 Attack success rate: 96.13%
# Seed: 0     	 Attack success rate: 67.79%
# Seed: 2     	 Attack success rate: 8.7%

# %%
df_fmr1000.T.mean().to_list()[0]
# Out:
# 41.010000000000005

# %%
permutation_complexity = [0, 
                          2, 
                         3,
                         4]

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
df_fmr10.T.plot(kind='bar', ax=ax,  label='seed')
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
ax.legend(["Attack success rate"])
#ax.axhline(y = df_fmr10.T.mean().to_list()[0], 
#           color = sns.color_palette("colorblind")[3], linestyle="--",
#           label = f"Mean attack rate")
ax.set_xticklabels([f"{complexity}" for seed, complexity in zip(df_fmr10.columns.to_list(), permutation_complexity)], rotation=0)
ax.set_ylim([0, 100])
#ax.annotate(f'Mean: {round(df_fmr10.T.mean().to_list()[0], 2)}%', (21, 55), ha='center', fontweight='normal', fontsize=9, c=sns.color_palette("colorblind")[3])
ax.set_xlabel("Permutation complexity")
ax.set_ylabel("Attack success %")
plt.savefig(f'random_seed_investigation/seed_arcface_128_th10.svg', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
df_fmr100.T.plot(kind='bar', ax=ax,  title="ArcFace TH100 Block size 128", label='seed')
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
ax.legend(["Attack success rate"])
ax.axhline(y = df_fmr100.T.mean().to_list()[0], 
           color = sns.color_palette("colorblind")[3], linestyle="--",
           label = f"Mean attack rate")
ax.set_xticklabels([f"{seed} ({complexity})" for seed, complexity in zip(df_fmr100.columns.to_list(), permutation_complexity)])
ax.annotate(f'Mean: {round(df_fmr100.T.mean().to_list()[0], 2)}%', (21, 38), ha='center', fontweight='normal', fontsize=9, c=sns.color_palette("colorblind")[3])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
df_fmr100.T.plot(kind='bar', ax=ax,  label='seed')
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
ax.legend(["Attack success rate"])
#ax.axhline(y = df_fmr10.T.mean().to_list()[0], 
#           color = sns.color_palette("colorblind")[3], linestyle="--",
#           label = f"Mean attack rate")
ax.set_xticklabels([f"{complexity}" for seed, complexity in zip(df_fmr100.columns.to_list(), permutation_complexity)], rotation=0)
ax.set_ylim([0, 100])
#ax.annotate(f'Mean: {round(df_fmr10.T.mean().to_list()[0], 2)}%', (21, 55), ha='center', fontweight='normal', fontsize=9, c=sns.color_palette("colorblind")[3])
ax.set_xlabel("Permutation complexity")
ax.set_ylabel("Attack success %")
plt.savefig(f'random_seed_investigation/seed_arcface_128_th100.svg', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
df_fmr1000.T.plot(kind='bar', ax=ax,  title="ArcFace TH1000 Block size 128", label='seed')
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
ax.legend(["Attack success rate"])
ax.axhline(y = df_fmr1000.T.mean().to_list()[0], 
           color = sns.color_palette("colorblind")[3], linestyle="--",
           label = f"Mean attack rate")
ax.set_xticklabels([f"{seed} ({complexity})" for seed, complexity in zip(df_fmr1000.columns.to_list(), permutation_complexity)])
ax.annotate(f'Mean: {round(df_fmr1000.T.mean().to_list()[0], 2)}%', (21, 22), ha='center', fontweight='normal', fontsize=9, c=sns.color_palette("colorblind")[3])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 7), tight_layout = True)
df_fmr1000.T.plot(kind='bar', ax=ax,  label='seed')
ax.grid(visible=True, which='major', color='black', linewidth=0.075)
ax.legend(["Attack success rate"])
#ax.axhline(y = df_fmr10.T.mean().to_list()[0], 
#           color = sns.color_palette("colorblind")[3], linestyle="--",
#           label = f"Mean attack rate")
ax.set_xticklabels([f"{complexity}" for seed, complexity in zip(df_fmr1000.columns.to_list(), permutation_complexity)], rotation=0)
ax.set_ylim([0, 100])
#ax.annotate(f'Mean: {round(df_fmr10.T.mean().to_list()[0], 2)}%', (21, 55), ha='center', fontweight='normal', fontsize=9, c=sns.color_palette("colorblind")[3])
ax.set_xlabel("Permutation complexity")
ax.set_ylabel("Attack success %")
plt.savefig(f'random_seed_investigation/seed_arcface_128_th1000.svg', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Export dataset

# %%
# Original data frame

df
# Out:
#                                                     img_original  \
# 0         ../data/lfw_align/Aaron_Eckhart/Aaron_Eckhart_0001.png
# 1             ../data/lfw_align/Aaron_Guiel/Aaron_Guiel_0001.png
# 2     ../data/lfw_align/Aaron_Patterson/Aaron_Patterson_0001.png
# 3         ../data/lfw_align/Aaron_Peirsol/Aaron_Peirsol_0004.png
# 4               ../data/lfw_align/Aaron_Pena/Aaron_Pena_0001.png
# ...                                                          ...
# 2937        ../data/lfw_align/Zelma_Novelo/Zelma_Novelo_0001.png
# 2938            ../data/lfw_align/Zhang_Ziyi/Zhang_Ziyi_0003.png
# 2939                ../data/lfw_align/Zoe_Ball/Zoe_Ball_0001.png
# 2940    ../data/lfw_align/Zorica_Radovic/Zorica_Radovic_0001.png
# 2941        ../data/lfw_align/Zumrati_Juma/Zumrati_Juma_0001.png
#
#       img_original_quality                         embedding_original_arcface  \
# 0                 0.785188    ../data/features_cleaner/Aaron_Eckhart_0001.npy
# 1                 0.764814      ../data/features_cleaner/Aaron_Guiel_0001.npy
# 2                 0.737193  ../data/features_cleaner/Aaron_Patterson_0001.npy
# 3                 0.810206    ../data/features_cleaner/Aaron_Peirsol_0004.npy
# 4                 0.829048       ../data/features_cleaner/Aaron_Pena_0001.npy
# ...                    ...                                                ...
# 2937              0.834612     ../data/features_cleaner/Zelma_Novelo_0001.npy
# 2938              0.696282       ../data/features_cleaner/Zhang_Ziyi_0003.npy
# 2939              0.779261         ../data/features_cleaner/Zoe_Ball_0001.npy
# 2940              0.741519   ../data/features_cleaner/Zorica_Radovic_0001.npy
# 2941              0.470757     ../data/features_cleaner/Zumrati_Juma_0001.npy
#
#      gender_official              filename  \
# 0                  M    Aaron_Eckhart_0001
# 1                  M      Aaron_Guiel_0001
# 2                  M  Aaron_Patterson_0001
# 3                  M    Aaron_Peirsol_0004
# 4                  M       Aaron_Pena_0001
# ...              ...                   ...
# 2937               F     Zelma_Novelo_0001
# 2938               F       Zhang_Ziyi_0003
# 2939               F         Zoe_Ball_0001
# 2940               F   Zorica_Radovic_0001
# 2941               F     Zumrati_Juma_0001
#
#                                      embedding_original_elasticface  seed_9  \
# 0       ../data/lfw_align_embeddings_elastic/Aaron_Eckhart_0001.npy   0.388
# 1         ../data/lfw_align_embeddings_elastic/Aaron_Guiel_0001.npy   0.253
# 2     ../data/lfw_align_embeddings_elastic/Aaron_Patterson_0001.npy   0.358
# 3       ../data/lfw_align_embeddings_elastic/Aaron_Peirsol_0004.npy   0.383
# 4          ../data/lfw_align_embeddings_elastic/Aaron_Pena_0001.npy   0.485
# ...                                                             ...     ...
# 2937     ../data/lfw_align_embeddings_elastic/Zelma_Novelo_0001.npy   0.615
# 2938       ../data/lfw_align_embeddings_elastic/Zhang_Ziyi_0003.npy   0.207
# 2939         ../data/lfw_align_embeddings_elastic/Zoe_Ball_0001.npy   0.590
# 2940   ../data/lfw_align_embeddings_elastic/Zorica_Radovic_0001.npy   0.628
# 2941     ../data/lfw_align_embeddings_elastic/Zumrati_Juma_0001.npy   0.372
#
#       seed_5  seed_0  seed_2
# 0      0.296   0.208   0.049
# 1      0.130   0.091   0.015
# 2      0.343   0.123  -0.009
# 3      0.186   0.070  -0.011
# 4      0.284   0.141   0.046
# ...      ...     ...     ...
# 2937   0.336   0.133   0.023
# 2938   0.151   0.175   0.055
# 2939   0.378   0.132  -0.141
# 2940   0.356   0.254  -0.031
# 2941   0.143   0.199   0.168
#
# [2942 rows x 10 columns]

# %% [markdown]
# Todo:
#
# - block size 128
# - permutation complexity 2 (seed no. 5)
# - gender labels
# - templates from reconstructed faces
# - templates from original faces

# %%
df_export = df[['embedding_original_arcface', 'gender_official', 'filename', 'seed_5']]

# %%
df_export.rename(columns={'seed_5': 'cos_sim_permutation_complexity_2'}, inplace=True)
# Out:
# /tmp/ipykernel_1019/4017343000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export.rename(columns={'seed_5': 'cos_sim_permutation_complexity_2'}, inplace=True)

# %%
# Include filepath for PEMIU protected embeddings at permutation complexity 2
df_export['embedding_pemiu_128_seed5'] = df_export['filename'].apply(lambda x: f"{experiment_11_path}embedding_seed_5/{x}.npy")
# Out:
# /tmp/ipykernel_1019/1527105744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['embedding_pemiu_128_seed5'] = df_export['filename'].apply(lambda x: f"{experiment_11_path}embedding_seed_5/{x}.npy")

# %%
# Include filepath for image reconstructions at permutation complexity 2

df_results_seed_5 = pd.read_csv(f"{experiment_11_path}/sample_img_5/logs/sample_images_log_exp11.csv")

# %%
df_results_seed_5.rename(columns={'filename': 'reconstructed_img_from_embedding_perm_compl_2'}, inplace=True)
df_results_seed_5
# Out:
#      reconstructed_img_from_embedding_perm_compl_2       MAE  \
# 0                Aaron_Eckhart_0001_exp11_0000.png  0.221368
# 1                  Aaron_Guiel_0001_exp11_0001.png  0.321115
# 2              Aaron_Patterson_0001_exp11_0002.png  0.181040
# 3                Aaron_Peirsol_0004_exp11_0003.png  0.214889
# 4                   Aaron_Pena_0001_exp11_0004.png  0.198129
# ...                                            ...       ...
# 5744            Zorica_Radovic_0001_exp11_0016.png  0.251710
# 5745            Zulfiqar_Ahmed_0001_exp11_0017.png  0.358846
# 5746              Zumrati_Juma_0001_exp11_0018.png  0.200261
# 5747           Zurab_Tsereteli_0001_exp11_0019.png  0.233034
# 5748        Zydrunas_Ilgauskas_0001_exp11_0020.png  0.261758
#
#       Cosine Distance Bona Fide Embedding vs Input Embedding  \
# 0                                                      0.400
# 1                                                      0.334
# 2                                                      0.314
# 3                                                      0.377
# 4                                                      0.389
# ...                                                      ...
# 5744                                                   0.440
# 5745                                                   0.453
# 5746                                                   0.284
# 5747                                                   0.416
# 5748                                                   0.379
#
#       Cosine Distance Bona Fide Embedding vs Synthesised Image Embedding
# 0                                                                  0.296
# 1                                                                  0.130
# 2                                                                  0.343
# 3                                                                  0.186
# 4                                                                  0.284
# ...                                                                  ...
# 5744                                                               0.356
# 5745                                                               0.268
# 5746                                                               0.143
# 5747                                                               0.265
# 5748                                                               0.147
#
# [5749 rows x 4 columns]

# %%
df_results_seed_5['filename'] = df_results_seed_5['reconstructed_img_from_embedding_perm_compl_2'].apply(lambda x: x.split('_exp11_')[0])
df_results_seed_5
# Out:
#      reconstructed_img_from_embedding_perm_compl_2       MAE  \
# 0                Aaron_Eckhart_0001_exp11_0000.png  0.221368
# 1                  Aaron_Guiel_0001_exp11_0001.png  0.321115
# 2              Aaron_Patterson_0001_exp11_0002.png  0.181040
# 3                Aaron_Peirsol_0004_exp11_0003.png  0.214889
# 4                   Aaron_Pena_0001_exp11_0004.png  0.198129
# ...                                            ...       ...
# 5744            Zorica_Radovic_0001_exp11_0016.png  0.251710
# 5745            Zulfiqar_Ahmed_0001_exp11_0017.png  0.358846
# 5746              Zumrati_Juma_0001_exp11_0018.png  0.200261
# 5747           Zurab_Tsereteli_0001_exp11_0019.png  0.233034
# 5748        Zydrunas_Ilgauskas_0001_exp11_0020.png  0.261758
#
#       Cosine Distance Bona Fide Embedding vs Input Embedding  \
# 0                                                      0.400
# 1                                                      0.334
# 2                                                      0.314
# 3                                                      0.377
# 4                                                      0.389
# ...                                                      ...
# 5744                                                   0.440
# 5745                                                   0.453
# 5746                                                   0.284
# 5747                                                   0.416
# 5748                                                   0.379
#
#       Cosine Distance Bona Fide Embedding vs Synthesised Image Embedding  \
# 0                                                                  0.296
# 1                                                                  0.130
# 2                                                                  0.343
# 3                                                                  0.186
# 4                                                                  0.284
# ...                                                                  ...
# 5744                                                               0.356
# 5745                                                               0.268
# 5746                                                               0.143
# 5747                                                               0.265
# 5748                                                               0.147
#
#                      filename
# 0          Aaron_Eckhart_0001
# 1            Aaron_Guiel_0001
# 2        Aaron_Patterson_0001
# 3          Aaron_Peirsol_0004
# 4             Aaron_Pena_0001
# ...                       ...
# 5744      Zorica_Radovic_0001
# 5745      Zulfiqar_Ahmed_0001
# 5746        Zumrati_Juma_0001
# 5747     Zurab_Tsereteli_0001
# 5748  Zydrunas_Ilgauskas_0001
#
# [5749 rows x 5 columns]

# %%
df_export = df_export.merge(df_results_seed_5[['filename', 'reconstructed_img_from_embedding_perm_compl_2']], on='filename')
df_export
# Out:
#                              embedding_original_arcface gender_official  \
# 0       ../data/features_cleaner/Aaron_Eckhart_0001.npy               M
# 1         ../data/features_cleaner/Aaron_Guiel_0001.npy               M
# 2     ../data/features_cleaner/Aaron_Patterson_0001.npy               M
# 3       ../data/features_cleaner/Aaron_Peirsol_0004.npy               M
# 4          ../data/features_cleaner/Aaron_Pena_0001.npy               M
# ...                                                 ...             ...
# 2937     ../data/features_cleaner/Zelma_Novelo_0001.npy               F
# 2938       ../data/features_cleaner/Zhang_Ziyi_0003.npy               F
# 2939         ../data/features_cleaner/Zoe_Ball_0001.npy               F
# 2940   ../data/features_cleaner/Zorica_Radovic_0001.npy               F
# 2941     ../data/features_cleaner/Zumrati_Juma_0001.npy               F
#
#                   filename  cos_sim_permutation_complexity_2  \
# 0       Aaron_Eckhart_0001                             0.296
# 1         Aaron_Guiel_0001                             0.130
# 2     Aaron_Patterson_0001                             0.343
# 3       Aaron_Peirsol_0004                             0.186
# 4          Aaron_Pena_0001                             0.284
# ...                    ...                               ...
# 2937     Zelma_Novelo_0001                             0.336
# 2938       Zhang_Ziyi_0003                             0.151
# 2939         Zoe_Ball_0001                             0.378
# 2940   Zorica_Radovic_0001                             0.356
# 2941     Zumrati_Juma_0001                             0.143
#
#                                                                                                       embedding_pemiu_128_seed5  \
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Eckhart_0001.npy
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Guiel_0001.npy
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Patterson_0001.npy
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Peirsol_0004.npy
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Pena_0001.npy
# ...                                                                                                                         ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zelma_Novelo_0001.npy
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zhang_Ziyi_0003.npy
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zoe_Ball_0001.npy
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zorica_Radovic_0001.npy
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zumrati_Juma_0001.npy
#
#      reconstructed_img_from_embedding_perm_compl_2
# 0                Aaron_Eckhart_0001_exp11_0000.png
# 1                  Aaron_Guiel_0001_exp11_0001.png
# 2              Aaron_Patterson_0001_exp11_0002.png
# 3                Aaron_Peirsol_0004_exp11_0003.png
# 4                   Aaron_Pena_0001_exp11_0004.png
# ...                                            ...
# 2937              Zelma_Novelo_0001_exp11_0004.png
# 2938                Zhang_Ziyi_0003_exp11_0008.png
# 2939                  Zoe_Ball_0001_exp11_0014.png
# 2940            Zorica_Radovic_0001_exp11_0016.png
# 2941              Zumrati_Juma_0001_exp11_0018.png
#
# [2942 rows x 6 columns]

# %%
df_export['reconstructed_img_from_embedding_perm_compl_2'] = df_export['reconstructed_img_from_embedding_perm_compl_2'].apply(lambda x: f'{experiment_11_path}sample_img_5/{x}')
df_export
# Out:
#                              embedding_original_arcface gender_official  \
# 0       ../data/features_cleaner/Aaron_Eckhart_0001.npy               M
# 1         ../data/features_cleaner/Aaron_Guiel_0001.npy               M
# 2     ../data/features_cleaner/Aaron_Patterson_0001.npy               M
# 3       ../data/features_cleaner/Aaron_Peirsol_0004.npy               M
# 4          ../data/features_cleaner/Aaron_Pena_0001.npy               M
# ...                                                 ...             ...
# 2937     ../data/features_cleaner/Zelma_Novelo_0001.npy               F
# 2938       ../data/features_cleaner/Zhang_Ziyi_0003.npy               F
# 2939         ../data/features_cleaner/Zoe_Ball_0001.npy               F
# 2940   ../data/features_cleaner/Zorica_Radovic_0001.npy               F
# 2941     ../data/features_cleaner/Zumrati_Juma_0001.npy               F
#
#                   filename  cos_sim_permutation_complexity_2  \
# 0       Aaron_Eckhart_0001                             0.296
# 1         Aaron_Guiel_0001                             0.130
# 2     Aaron_Patterson_0001                             0.343
# 3       Aaron_Peirsol_0004                             0.186
# 4          Aaron_Pena_0001                             0.284
# ...                    ...                               ...
# 2937     Zelma_Novelo_0001                             0.336
# 2938       Zhang_Ziyi_0003                             0.151
# 2939         Zoe_Ball_0001                             0.378
# 2940   Zorica_Radovic_0001                             0.356
# 2941     Zumrati_Juma_0001                             0.143
#
#                                                                                                       embedding_pemiu_128_seed5  \
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Eckhart_0001.npy
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Guiel_0001.npy
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Patterson_0001.npy
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Peirsol_0004.npy
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Pena_0001.npy
# ...                                                                                                                         ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zelma_Novelo_0001.npy
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zhang_Ziyi_0003.npy
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zoe_Ball_0001.npy
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zorica_Radovic_0001.npy
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zumrati_Juma_0001.npy
#
#                                                                                          reconstructed_img_from_embedding_perm_compl_2
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Eckhart_0001_exp11_0000.png
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Guiel_0001_exp11_0001.png
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Patterson_0001_exp11_0002.png
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Peirsol_0004_exp11_0003.png
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Pena_0001_exp11_0004.png
# ...                                                                                                                                ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zelma_Novelo_0001_exp11_0004.png
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zhang_Ziyi_0003_exp11_0008.png
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zoe_Ball_0001_exp11_0014.png
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zorica_Radovic_0001_exp11_0016.png
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zumrati_Juma_0001_exp11_0018.png
#
# [2942 rows x 6 columns]

# %%
# Generate embeddings from reconstructed images
gen_emb = GenerateEmbeddings()
path = f'{experiment_11_path}sample_img_5_embeddings'
os.makedirs(path, exist_ok=True)

for image, filename in zip(df_export['reconstructed_img_from_embedding_perm_compl_2'].tolist(), df_export['filename'].tolist()):
    embedding = gen_emb.embedding_from_img(image)
    np.save(f"{path}/{filename}.npy", embedding)
# Out:
# The torch device is: cuda

# %%
df_export['embeddings_from_reconsutrcted_img'] = df_export['filename'].apply(lambda x: f'{experiment_11_path}sample_img_5_embeddings/{x}.npy')
df_export
# Out:
#                              embedding_original_arcface gender_official  \
# 0       ../data/features_cleaner/Aaron_Eckhart_0001.npy               M
# 1         ../data/features_cleaner/Aaron_Guiel_0001.npy               M
# 2     ../data/features_cleaner/Aaron_Patterson_0001.npy               M
# 3       ../data/features_cleaner/Aaron_Peirsol_0004.npy               M
# 4          ../data/features_cleaner/Aaron_Pena_0001.npy               M
# ...                                                 ...             ...
# 2937     ../data/features_cleaner/Zelma_Novelo_0001.npy               F
# 2938       ../data/features_cleaner/Zhang_Ziyi_0003.npy               F
# 2939         ../data/features_cleaner/Zoe_Ball_0001.npy               F
# 2940   ../data/features_cleaner/Zorica_Radovic_0001.npy               F
# 2941     ../data/features_cleaner/Zumrati_Juma_0001.npy               F
#
#                   filename  cos_sim_permutation_complexity_2  \
# 0       Aaron_Eckhart_0001                             0.296
# 1         Aaron_Guiel_0001                             0.130
# 2     Aaron_Patterson_0001                             0.343
# 3       Aaron_Peirsol_0004                             0.186
# 4          Aaron_Pena_0001                             0.284
# ...                    ...                               ...
# 2937     Zelma_Novelo_0001                             0.336
# 2938       Zhang_Ziyi_0003                             0.151
# 2939         Zoe_Ball_0001                             0.378
# 2940   Zorica_Radovic_0001                             0.356
# 2941     Zumrati_Juma_0001                             0.143
#
#                                                                                                       embedding_pemiu_128_seed5  \
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Eckhart_0001.npy
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Guiel_0001.npy
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Patterson_0001.npy
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Peirsol_0004.npy
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Aaron_Pena_0001.npy
# ...                                                                                                                         ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zelma_Novelo_0001.npy
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zhang_Ziyi_0003.npy
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zoe_Ball_0001.npy
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zorica_Radovic_0001.npy
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/embedding_seed_5/Zumrati_Juma_0001.npy
#
#                                                                                          reconstructed_img_from_embedding_perm_compl_2  \
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Eckhart_0001_exp11_0000.png
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Guiel_0001_exp11_0001.png
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Patterson_0001_exp11_0002.png
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Peirsol_0004_exp11_0003.png
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Aaron_Pena_0001_exp11_0004.png
# ...                                                                                                                                ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zelma_Novelo_0001_exp11_0004.png
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zhang_Ziyi_0003_exp11_0008.png
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zoe_Ball_0001_exp11_0014.png
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zorica_Radovic_0001_exp11_0016.png
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5/Zumrati_Juma_0001_exp11_0018.png
#
#                                                                                                      embeddings_from_reconsutrcted_img
# 0       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Aaron_Eckhart_0001.npy
# 1         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Aaron_Guiel_0001.npy
# 2     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Aaron_Patterson_0001.npy
# 3       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Aaron_Peirsol_0004.npy
# 4          ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Aaron_Pena_0001.npy
# ...                                                                                                                                ...
# 2937     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Zelma_Novelo_0001.npy
# 2938       ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Zhang_Ziyi_0003.npy
# 2939         ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Zoe_Ball_0001.npy
# 2940   ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Zorica_Radovic_0001.npy
# 2941     ../recreate_icip2022_face_reconstruction/experiments/experiment_11_pemiu_random/sample_img_5_embeddings/Zumrati_Juma_0001.npy
#
# [2942 rows x 7 columns]

# %%
# Export

face_extractor_name = 'arcface' 
export_path = f"../export/{face_extractor_name}_pemiu128_permcomp2_balanced"
os.makedirs(export_path, exist_ok=True)

os.makedirs(f'{export_path}/embeddings_original', exist_ok=True)
os.makedirs(f'{export_path}/embeddings_pemiu', exist_ok=True)
os.makedirs(f'{export_path}/reconstructed_img', exist_ok=True)
os.makedirs(f'{export_path}/embeddings_from_reconstructed_img', exist_ok=True)

# %%
# Copy files to export location

for element in df_export['embedding_original_arcface'].tolist():
    shutil.copy(element, f'{export_path}/embeddings_original')

# %%
for element in df_export['embedding_pemiu_128_seed5'].tolist():
    shutil.copy(element, f'{export_path}/embeddings_pemiu')
    
for element in df_export['reconstructed_img_from_embedding_perm_compl_2'].tolist():
    shutil.copy(element, f'{export_path}/reconstructed_img')
    
for element in df_export['embeddings_from_reconsutrcted_img'].tolist():
    shutil.copy(element, f'{export_path}/embeddings_from_reconstructed_img')

# %%
# Modify dataframe to include relative filepaths

df_export['embedding_original_arcface'] = df_export['embedding_original_arcface'].apply(lambda x: f"./embeddings_original/{x.split('/')[-1]}")
df_export['embedding_pemiu_128_seed5'] = df_export['embedding_pemiu_128_seed5'].apply(lambda x: f"./embeddings_pemiu/{x.split('/')[-1]}")
df_export['reconstructed_img_from_embedding_perm_compl_2'] = df_export['reconstructed_img_from_embedding_perm_compl_2'].apply(lambda x: f"./reconstructed_img/{x.split('/')[-1]}")
df_export['embeddings_from_reconsutrcted_img'] = df_export['embeddings_from_reconsutrcted_img'].apply(lambda x: f"./embeddings_from_reconstructed_img/{x.split('/')[-1]}")

# %%
df_export
# Out:
#                           embedding_original_arcface gender_official  \
# 0       ./embeddings_original/Aaron_Eckhart_0001.npy               M
# 1         ./embeddings_original/Aaron_Guiel_0001.npy               M
# 2     ./embeddings_original/Aaron_Patterson_0001.npy               M
# 3       ./embeddings_original/Aaron_Peirsol_0004.npy               M
# 4          ./embeddings_original/Aaron_Pena_0001.npy               M
# ...                                              ...             ...
# 2937     ./embeddings_original/Zelma_Novelo_0001.npy               F
# 2938       ./embeddings_original/Zhang_Ziyi_0003.npy               F
# 2939         ./embeddings_original/Zoe_Ball_0001.npy               F
# 2940   ./embeddings_original/Zorica_Radovic_0001.npy               F
# 2941     ./embeddings_original/Zumrati_Juma_0001.npy               F
#
#                   filename  cos_sim_permutation_complexity_2  \
# 0       Aaron_Eckhart_0001                             0.296
# 1         Aaron_Guiel_0001                             0.130
# 2     Aaron_Patterson_0001                             0.343
# 3       Aaron_Peirsol_0004                             0.186
# 4          Aaron_Pena_0001                             0.284
# ...                    ...                               ...
# 2937     Zelma_Novelo_0001                             0.336
# 2938       Zhang_Ziyi_0003                             0.151
# 2939         Zoe_Ball_0001                             0.378
# 2940   Zorica_Radovic_0001                             0.356
# 2941     Zumrati_Juma_0001                             0.143
#
#                         embedding_pemiu_128_seed5  \
# 0       ./embeddings_pemiu/Aaron_Eckhart_0001.npy
# 1         ./embeddings_pemiu/Aaron_Guiel_0001.npy
# 2     ./embeddings_pemiu/Aaron_Patterson_0001.npy
# 3       ./embeddings_pemiu/Aaron_Peirsol_0004.npy
# 4          ./embeddings_pemiu/Aaron_Pena_0001.npy
# ...                                           ...
# 2937     ./embeddings_pemiu/Zelma_Novelo_0001.npy
# 2938       ./embeddings_pemiu/Zhang_Ziyi_0003.npy
# 2939         ./embeddings_pemiu/Zoe_Ball_0001.npy
# 2940   ./embeddings_pemiu/Zorica_Radovic_0001.npy
# 2941     ./embeddings_pemiu/Zumrati_Juma_0001.npy
#
#                 reconstructed_img_from_embedding_perm_compl_2  \
# 0       ./reconstructed_img/Aaron_Eckhart_0001_exp11_0000.png
# 1         ./reconstructed_img/Aaron_Guiel_0001_exp11_0001.png
# 2     ./reconstructed_img/Aaron_Patterson_0001_exp11_0002.png
# 3       ./reconstructed_img/Aaron_Peirsol_0004_exp11_0003.png
# 4          ./reconstructed_img/Aaron_Pena_0001_exp11_0004.png
# ...                                                       ...
# 2937     ./reconstructed_img/Zelma_Novelo_0001_exp11_0004.png
# 2938       ./reconstructed_img/Zhang_Ziyi_0003_exp11_0008.png
# 2939         ./reconstructed_img/Zoe_Ball_0001_exp11_0014.png
# 2940   ./reconstructed_img/Zorica_Radovic_0001_exp11_0016.png
# 2941     ./reconstructed_img/Zumrati_Juma_0001_exp11_0018.png
#
#                                  embeddings_from_reconsutrcted_img
# 0       ./embeddings_from_reconstructed_img/Aaron_Eckhart_0001.npy
# 1         ./embeddings_from_reconstructed_img/Aaron_Guiel_0001.npy
# 2     ./embeddings_from_reconstructed_img/Aaron_Patterson_0001.npy
# 3       ./embeddings_from_reconstructed_img/Aaron_Peirsol_0004.npy
# 4          ./embeddings_from_reconstructed_img/Aaron_Pena_0001.npy
# ...                                                            ...
# 2937     ./embeddings_from_reconstructed_img/Zelma_Novelo_0001.npy
# 2938       ./embeddings_from_reconstructed_img/Zhang_Ziyi_0003.npy
# 2939         ./embeddings_from_reconstructed_img/Zoe_Ball_0001.npy
# 2940   ./embeddings_from_reconstructed_img/Zorica_Radovic_0001.npy
# 2941     ./embeddings_from_reconstructed_img/Zumrati_Juma_0001.npy
#
# [2942 rows x 7 columns]

# %%
df_export.to_csv(f"{export_path}/dataframe.csv")
