# %%
import pandas as pd
import os

# %%
df = pd.read_csv("files/thesis-acronyms.txt", names=['acronym'])
df['edit'] = df['acronym'].apply(lambda x: x.split('{')[1][:-1])
df.sort_values(by=['edit'], inplace=True)
df['acronym'].to_csv("files/tesis-acronyms-sorted.txt", index=False, header=False)
df
# Out:
#                                               acronym    edit
# 29    \acro{B-PETs}{Biometric Privacy–Enhancing Te...  B-PETs
# 25    \acro{BLUFR}{Benchmark of Large-scale Uncons...   BLUFR
# 22           \acro{CNN}{Convolutional Neural Network}     CNN
# 1               \acro{COTS}{Commercial off-the-shelf}    COTS
# 14    \acro{DCGAN}{Deep Convolutional Generative A...   DCGAN
# 20    \acro{DIDFE}{Different Image-Different Featu...   DIDFE
# 18    \acro{DISFE}{Different Image-Same Feature Ex...   DISFE
# 4     \acro{DSSIM}{Dissimilarity Structural Index ...   DSSIM
# 13                       \acro{EER}{Equal Error Rate}     EER
# 9                   \acro{FAR}{False Acceptance Rate}     FAR
# 2                        \acro{FFHQ}{Flickr-Faces-HQ}    FFHQ
# 8                        \acro{FMR}{False Match Rate}     FMR
# 12                  \acro{FNMR}{False Non-Match Rate}    FNMR
# 23                       \acro{GA}{Genetic Algorithm}      GA
# ...
